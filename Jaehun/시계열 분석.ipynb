# %% [markdown]
# # 시계열 분석

# %% [markdown]
# 참고 자료
# https://kerpect.tistory.com/161
# https://otexts.com/fppkr/index.html
# https://m.blog.naver.com/dsz08082/222042702104

# %% [markdown]
# ### [1] **정의**
# 과거로부터 현재까지의 변화를 통해서 향후 미래를 예측
#
# ---

# %% [markdown]
# ### [2] **분류**
# **(1) 정상적 시계열**
# 시간의 추이와 관계엾이 평균과 분산이 일정
# **(2) 비정상적 시계열**
# 시간에 추이에 따라서 점진적으로 증가
#
# * 대부분은 시계열 자료는 비정상성 시계열 자료
# => 분석하기 쉬운 정상성 시계열 자료로 변환
# 1. 평균이 일정하지 않은 경우 : 차분(현시점 자료에서 이전 시점 자료를 빼는 것)을 통해 정상화
#     - 일반차분 : 바로 전 시점의 자료를 빼는 것
#     - 계절차분 : 여러 시점 전의 자료를 빼는 것
# 2. 분산이 일정하지 않은 경우 : 변환(자연로그)을 통해 정상화
#
# ---

# %% [markdown]
# ### [3] **시계열 분석 특징**
# 1) y 변수 존재  : 시간을 독립변수로 시계열을 종속변수로 사용
# 2) 미래 추정    : 과거와 현재의 현상을 파악하여 미래를 추정
# 3) 계절성 자료  : 시간 축을 기준으로 계절성이 있는 자료를 데이터 셋으로 이용
# 4) 모수 검정    : 선형성, 정규성, 등분산성 가정(모든 확률 변수가 같은 유한 분산임을 가정) 만족
# 5) 추론 기능    : 유의수준 판단 기준이 존재하는 추론 통계 방식
# 6) 활용 분야    : 경기예측, 판매예측, 주식시장분석, 예산 및 투자 분석, 교통수요 등
#
#
# ---

# %% [markdown]
# ### [4] **시계열 분석 적용 범위**
# 1) 기존 사실에 대한 결과 규명 ex) 시기별 분석을 통한 고객 구매 패턴 분석
# 2) 시계열자료 특성 규명 ex) 시기별에 영향을 주는 일반적인 요소(계절 등)를 분해해서 분석(시계열 요소 분해법)
# 3) 가까운 미래에 대한 시나리오 규명
# 4) 변수 간 관계 규명
# 5) 변수 제어 결과 규명 ex) 종속 변수를 제어하면 종속변수에는 어떤 영향을 끼치는가?)
#
# ---

# %% [markdown]
# ### [5] **시계열 데이터 특성**
# 1) 추세 변동 (Trend Variation)
# 2) 순환 변동 (Cyclical Variation)
# 3) 계절 변동 (Seasonal Variation)
# 4) 불규칙 변동 (Irregular Variation) : 설명할 수  없는 요인으로 인한 예측 불가능한 변동 요인(white noise)

# %% [markdown]
# ### [6] 시계열 분석 절차

# %%
from IPython.display import Image
Image("./image/img_01.PNG")

# %% [markdown]
# 모델
# **정상성을 가진 시계열 모형**
#     - 자기회귀모형(AR)
#     - 이동평균모형(MA)
#     - 자기회귀이동평균모형(ARMA)
# **비정상성을 가진 시계열 모형**
#     -자기회귀누적이동평균모형(ARIMA)
